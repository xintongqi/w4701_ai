# %% [markdown]
# Name: Amy Qi
#
# UNI: xq2224

# %% [markdown]
# # MNIST Sign Language

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics         import accuracy_score
from sklearn.model_selection import train_test_split

import keras
from keras.utils  import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
class SignLanguage:
    def __init__(self):
        self.model = None

        self.data = {
            "train": None,
            "test" : None
        }
        self.create_model()

    def create_model(self):
        """
        Create a CNN model and save it to self.model
        """
        model = Sequential()
        model.add(Conv2D(32, kernel_size=(5, 5), padding='same', activation='relu', input_shape=(28, 28, 1)))
        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(128, kernel_size=(5, 5), padding='same', activation='relu'))

        model.add(Flatten())
        model.add(Dense(512, activation='relu'))
        model.add(Dropout(rate=0.2))
        model.add(Dense(25, activation='softmax')) # for 25 classes

        model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

        self.model = model

    def prepare_data(self, images, labels):
        """
        Use this method to normalize the dataset and split it into train/test.
        Save your data in self.data["train"] and self.data["test"] as a tuple
        of (images, labels)

        :param images numpy array of size (num_examples, 28*28)
        :param labels numpy array of size (num_examples, )
        """
        images_reshaped = np.array([np.reshape(curVec/255.0,(28,28,1)) for curVec in images])

        x_train, x_test, y_train, y_test = train_test_split(images_reshaped, labels, test_size=0.2, shuffle=True)

        # print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)

        self.data = {
            "train": (x_train, y_train),
            "test": (x_test, y_test)
        }


    def train(self, batch_size:int=128, epochs:int=50, verbose:int=1):
        """
        Use model.fit() to train your model. Make sure to return the history for a neat visualization.

        :param batch_size The batch size to use for training
        :param epochs     Number of epochs to use for training
        :param verbose    Whether or not to print training output
        """
        self.model.summary()
        history = self.model.fit(self.data['train'][0], self.data['train'][1],
                                 validation_data=self.data['test'], batch_size=batch_size,
                                 epochs=epochs, verbose=verbose)
        return history

    def predict(self, data):
        """
        Use the trained model to predict labels for test data.

        :param data: numpy array of test images
        :return a numpy array of test labels. array size = (num_examples, )
        """

        data_reshaped = np.array([np.reshape(curVec/255.0,(28,28,1)) for curVec in data])
        return np.argmax(self.model.predict(data_reshaped), axis=1)


    def visualize_data(self, data):
        """
        Visualizing the hand gestures

        :param data: numpy array of images
        """
        if data is None: return

        nrows, ncols = 5, 5
        fig, axs = plt.subplots(nrows, ncols, figsize=(10, 10), sharex=True, sharey=True)
        plt.subplots_adjust(wspace=0, hspace=0)

        for i in range(nrows):
            for j in range(ncols):
                axs[i][j].imshow(data[0][i*ncols+j].reshape(28, 28), cmap='gray')
        plt.show()

    def visualize_accuracy(self, history):
        """
        Plots out the accuracy measures given a keras history object

        :param history: return value from model.fit()
        """
        if history is None: return

        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title("Accuracy")
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.legend(['train','test'])
        plt.show()

# %% [markdown]
# # Grading Script
#
# Do NOT modify this section

# %%
if __name__=="__main__":
    train = pd.read_csv('train.csv')
    test  = pd.read_csv('test.csv')

    train_labels, test_labels = train['label'].values, test['label'].values
    train.drop('label', axis=1, inplace=True)
    test.drop('label', axis=1, inplace=True)

    num_classes = test_labels.max() + 1
    train_images, test_images = train.values, test.values

    print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
# Out:
# (27455, 784) (27455,) (7172, 784) (7172,)

# %%
if __name__=="__main__":
    my_model = SignLanguage()
    my_model.prepare_data(train_images, train_labels)

# %%
if __name__=="__main__":
    my_model.visualize_data(my_model.data["train"])

# %%
if __name__=="__main__":
    history = my_model.train(epochs=30, verbose=1)
    my_model.visualize_accuracy(history)
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_76 (Conv2D)          (None, 28, 28, 32)        832
#
#  max_pooling2d_71 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  conv2d_77 (Conv2D)          (None, 14, 14, 64)        51264
#
#  max_pooling2d_72 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  conv2d_78 (Conv2D)          (None, 7, 7, 64)          102464
#
#  max_pooling2d_73 (MaxPooli  (None, 3, 3, 64)          0
#  ng2D)
#
#  conv2d_79 (Conv2D)          (None, 3, 3, 128)         204928
#
#  flatten_19 (Flatten)        (None, 1152)              0
#
#  dense_38 (Dense)            (None, 512)               590336
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_39 (Dense)            (None, 25)                12825
#
# =================================================================
# Total params: 962649 (3.67 MB)
# Trainable params: 962649 (3.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 172/172 [==============================] - 4s 10ms/step - loss: 1.8095 - accuracy: 0.4282 - val_loss: 0.3840 - val_accuracy: 0.8818
# Epoch 2/30
# 172/172 [==============================] - 1s 8ms/step - loss: 0.1594 - accuracy: 0.9504 - val_loss: 0.0403 - val_accuracy: 0.9867
# Epoch 3/30
# 172/172 [==============================] - 1s 9ms/step - loss: 0.0243 - accuracy: 0.9944 - val_loss: 0.0145 - val_accuracy: 0.9982
# Epoch 4/30
# 172/172 [==============================] - 1s 9ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 8.0989e-04 - val_accuracy: 0.9998
# Epoch 5/30
# 172/172 [==============================] - 2s 9ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 2.9968e-04 - val_accuracy: 0.9998
# Epoch 6/30
# 172/172 [==============================] - 1s 9ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.0154 - val_accuracy: 0.9973
# Epoch 7/30
# 172/172 [==============================] - 2s 11ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 7.5901e-04 - val_accuracy: 0.9998
# Epoch 8/30
# 172/172 [==============================] - 2s 11ms/step - loss: 2.0135e-04 - accuracy: 1.0000 - val_loss: 3.0106e-04 - val_accuracy: 0.9998
# Epoch 9/30
# 172/172 [==============================] - 1s 9ms/step - loss: 1.0932e-04 - accuracy: 1.0000 - val_loss: 5.9940e-04 - val_accuracy: 0.9998
# Epoch 10/30
# 172/172 [==============================] - 1s 9ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0168 - val_accuracy: 0.9953
# Epoch 11/30
# 172/172 [==============================] - 1s 9ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.0048 - val_accuracy: 0.9995
# Epoch 12/30
# 172/172 [==============================] - 2s 9ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 6.5697e-04 - val_accuracy: 1.0000
# Epoch 13/30
# 172/172 [==============================] - 1s 8ms/step - loss: 2.0860e-04 - accuracy: 1.0000 - val_loss: 1.6611e-05 - val_accuracy: 1.0000
# Epoch 14/30
# 172/172 [==============================] - 1s 9ms/step - loss: 3.9566e-05 - accuracy: 1.0000 - val_loss: 1.3713e-05 - val_accuracy: 1.0000
# Epoch 15/30
# 172/172 [==============================] - 2s 10ms/step - loss: 4.6933e-05 - accuracy: 1.0000 - val_loss: 6.5219e-06 - val_accuracy: 1.0000
# Epoch 16/30
# 172/172 [==============================] - 2s 10ms/step - loss: 2.4251e-05 - accuracy: 1.0000 - val_loss: 4.0703e-06 - val_accuracy: 1.0000
# Epoch 17/30
# 172/172 [==============================] - 2s 11ms/step - loss: 2.0133e-05 - accuracy: 1.0000 - val_loss: 3.0544e-06 - val_accuracy: 1.0000
# Epoch 18/30
# 172/172 [==============================] - 1s 8ms/step - loss: 1.6791e-05 - accuracy: 1.0000 - val_loss: 2.2755e-06 - val_accuracy: 1.0000
# Epoch 19/30
# 172/172 [==============================] - 1s 9ms/step - loss: 1.2521e-05 - accuracy: 1.0000 - val_loss: 1.8900e-06 - val_accuracy: 1.0000
# Epoch 20/30
# 172/172 [==============================] - 1s 9ms/step - loss: 7.3643e-06 - accuracy: 1.0000 - val_loss: 1.5520e-06 - val_accuracy: 1.0000
# Epoch 21/30
# 172/172 [==============================] - 1s 9ms/step - loss: 8.7841e-06 - accuracy: 1.0000 - val_loss: 1.1955e-06 - val_accuracy: 1.0000
# Epoch 22/30
# 172/172 [==============================] - 1s 9ms/step - loss: 9.2525e-06 - accuracy: 1.0000 - val_loss: 1.1398e-06 - val_accuracy: 1.0000
# Epoch 23/30
# 172/172 [==============================] - 1s 9ms/step - loss: 5.8435e-06 - accuracy: 1.0000 - val_loss: 9.2748e-07 - val_accuracy: 1.0000
# Epoch 24/30
# 172/172 [==============================] - 2s 10ms/step - loss: 5.6252e-06 - accuracy: 1.0000 - val_loss: 8.1236e-07 - val_accuracy: 1.0000
# Epoch 25/30
# 172/172 [==============================] - 2s 11ms/step - loss: 4.6789e-06 - accuracy: 1.0000 - val_loss: 6.4292e-07 - val_accuracy: 1.0000
# Epoch 26/30
# 172/172 [==============================] - 2s 9ms/step - loss: 3.7659e-06 - accuracy: 1.0000 - val_loss: 5.4104e-07 - val_accuracy: 1.0000
# Epoch 27/30
# 172/172 [==============================] - 1s 9ms/step - loss: 2.9530e-06 - accuracy: 1.0000 - val_loss: 4.7672e-07 - val_accuracy: 1.0000
# Epoch 28/30
# 172/172 [==============================] - 1s 9ms/step - loss: 2.8925e-06 - accuracy: 1.0000 - val_loss: 4.0586e-07 - val_accuracy: 1.0000
# Epoch 29/30
# 172/172 [==============================] - 1s 9ms/step - loss: 2.6145e-06 - accuracy: 1.0000 - val_loss: 4.0092e-07 - val_accuracy: 1.0000
# Epoch 30/30
# 172/172 [==============================] - 1s 9ms/step - loss: 3.3604e-06 - accuracy: 1.0000 - val_loss: 3.8195e-07 - val_accuracy: 1.0000

# %%
if __name__=="__main__":
    y_pred = my_model.predict(test_images)
    accuracy = accuracy_score(test_labels, y_pred)
    print(accuracy)
# Out:
# 225/225 [==============================] - 1s 2ms/step
# 0.9619353039598438
